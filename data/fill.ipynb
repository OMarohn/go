# %% [markdown]
# # Füllen mit Beispieldaten

# %%
import requests
import pandas

token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IjNxdFFwY1ZZN0RlRXhOamJBV095cCJ9.....vBqAkXp7DgmZBDUsS19h9T12ytD9uUTHFWsR8jk92dJ-jM75VhgGNO99kQ-lr0lydieE23d3iBEr86Rsp-qq_W4U08RLC6y1AtQS2WV5Qlw8j0bG31ZxdtzNIp_V7FcEbI7U0fNHgKQ-l25RwT5rP5nCX0u_hA3RcAiQbr8ADPmBCPJfoXNFi-9EECqm12TOkSSpwYMF7qEBqwZt8WiRIUcA6rJJ-EpsWZ6KaUXjbUZ_bkycI0Q0IbweCYv57Zi_dTwqHxDKLPPDEaZjLORkhoaN6zZUojqt2MpkFz85abJPBzCVIlszNsG1HlWdZIQib0VqgkDdAU51JKL3cM9F-Q"

df = pandas.read_csv("./coaster_db.csv")
df = df[df["height_ft"] > 0]

# %%
api_url ="http://localhost:8080/redis/coasters"
headers =  {"Content-Type":"application/json","Host":"kom.io","version":"v1","Authorization": "Bearer " + token}

for r in df.iterrows():
    id = r[0]
    data = r[1]
    jdata =  {"name": data["coaster_name"],
    "manufacture": str(data["Manufacturer"]),
    "id": "id"+str(id),
    "height": int(data["height_ft"])}
    #print(jdata)
    response = requests.post(api_url, json=jdata, headers=headers)
    print(response.status_code)
# Out:
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
# 400
